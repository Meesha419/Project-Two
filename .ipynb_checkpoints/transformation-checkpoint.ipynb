# %%
# Import dependencies

import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect
from datetime import date
import config

# %% [markdown]
# ## Extract CSVs into DataFrames

# %%
# CSV file #1

vaccinations_file = "country_vaccinations.csv"
vaccinations_df = pd.read_csv(vaccinations_file)
vaccinations_df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
# CSV file #2

covid_data_file = "worldwide_covid_data.csv"
covid_data_df = pd.read_csv(covid_data_file)
covid_data_df
# Out:
#     Country/Other  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0     Afghanistan       187037          7752         167226.0       12059.0
# 1         Albania       315337          3554         301444.0       10339.0
# 2         Algeria       267902          6877         179788.0       81237.0
# 3         Andorra        45793           154          45401.0         238.0
# 4          Angola       102301          1912          97149.0        3240.0
# ..            ...          ...           ...              ...           ...
# 204     Venezuela       537487          5766         526664.0        5057.0
# 205       Vietnam     11192043         43094        9957655.0     1191294.0
# 206         Yemen        11895          2152           9117.0         626.0
# 207        Zambia       330575          4015         325321.0        1239.0
# 208      Zimbabwe       256444          5581         250426.0         437.0
#
# ...

# %% [markdown]
# ## Transform manufacturer DataFrame

# %%
# TO BE DELETED
# Get the latest date in the data set
# latest_date = manufacturer_df['date'].max()
# latest_date

# filtered_manufacturer_df = manufacturer_df.loc[manufacturer_df['date'] == latest_date]
# filtered_manufacturer_df

# This resulted to only 2 rows!

# %%
# Get data at one timepoint (2022-03-29) from manufacturer_df

filtered_vaccinations_df = vaccinations_df.loc[vaccinations_df['date'] =="2022-03-29"]
filtered_vaccinations_df
# Out:
#                     country  iso_code        date  total_vaccinations  \
# 3303              Argentina       ARG  2022-03-29        9.650467e+07
# 4017                  Aruba       ABW  2022-03-29        1.692310e+05
# 4419              Australia       AUS  2022-03-29        5.624291e+07
# 5298             Azerbaijan       AZE  2022-03-29        1.342503e+07
# 6560             Bangladesh       BGD  2022-03-29        2.436427e+08
# 11085                Brazil       BRA  2022-03-29        4.135596e+08
# 12201              Bulgaria       BGR  2022-03-29        4.348404e+06
# 16225                 China       CHN  2022-03-29        3.263129e+09
# 18923               Croatia       HRV  2022-03-29        5.224151e+06
# 19609               Curacao       CUW  2022-03-29        2.465660e+05
# 20484               Czechia       CZE  2022-03-29        1.749205e+07
# 22455    Dominican Republic       DOM  2022-03-29        1.548488e+07
# ...

# %%
# Generate a new dataframe excluding date column

clean_vaccinations_df = filtered_vaccinations_df[["country", "total_vaccinations"]].copy()
clean_vaccinations_df.head()
# Out:
#          country  total_vaccinations
# 3303   Argentina          96504666.0
# 4017       Aruba            169231.0
# 4419   Australia          56242913.0
# 5298  Azerbaijan          13425032.0
# 6560  Bangladesh         243642749.0

# %% [markdown]
# ## Transform covid_data DataFrame

# %%
# Delete NaN values

clean_covid_data = covid_data_df.dropna(how="any")
clean_covid_data
# Out:
#     Country/Other  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0     Afghanistan       187037          7752         167226.0       12059.0
# 1         Albania       315337          3554         301444.0       10339.0
# 2         Algeria       267902          6877         179788.0       81237.0
# 3         Andorra        45793           154          45401.0         238.0
# 4          Angola       102301          1912          97149.0        3240.0
# ..            ...          ...           ...              ...           ...
# 204     Venezuela       537487          5766         526664.0        5057.0
# 205       Vietnam     11192043         43094        9957655.0     1191294.0
# 206         Yemen        11895          2152           9117.0         626.0
# 207        Zambia       330575          4015         325321.0        1239.0
# 208      Zimbabwe       256444          5581         250426.0         437.0
#
# ...

# %%
# Rename column "Country/Other" to "Country"

clean_covid_data.rename(columns= {'Country/Other' : 'Country'}, inplace = True)
clean_covid_data.head()

# code needs to be checked
# Out:
# C:\Users\archa\AppData\Local\Temp\ipykernel_22828\4245653979.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_covid_data.rename(columns= {'Country/Other' : 'Country'}, inplace = True)
#        Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0  Afghanistan       187037          7752         167226.0       12059.0
# 1      Albania       315337          3554         301444.0       10339.0
# 2      Algeria       267902          6877         179788.0       81237.0
# 3      Andorra        45793           154          45401.0         238.0
# 4       Angola       102301          1912          97149.0        3240.0
#
#    Tot Cases/ 1M pop  Deaths/ 1M pop  Total Tests  Tests/ 1M pop  Population
# ...

# %% [markdown]
# ## Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/covid-19_db"
engine = create_engine(f'postgresql://{connection_string}')
insp = inspect(engine)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 connection_string = "postgres:postgres@localhost:5432/covid-19_db"
# ----> 2 engine = create_engine(f'postgresql://{connection_string}')
#       3 insp = inspect(engine)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:560, in create_engine(url, **kwargs)
#     558         if k in kwargs:
# ...

# %%
# Confirm tables

insp.get_table_names()

# %% [markdown]
# ## Load DataFrames into database

# %%
filtered_manufacturer_df.to_sql(name='manufacturer', con=engine, if_exists='append', index=True)

# %%
clean_covid_data.to_sql(name='covid_data', con=engine, if_exists='append', index=True)
